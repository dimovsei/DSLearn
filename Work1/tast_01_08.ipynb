# %%
#Домашняя работа №1
#8.	Создайте словарь с пятью парами «ключ-значение», где ключи - названия фруктов, а значения - их цвета. Выведите только те фрукты, цвет которых содержит букву 'к'.
MyFruitDict = {"Апельсин":"оранжевый",
          "Банан":"желтый",
          "Груша":"зеленая",
          "Дуриан":"коричневый",
          "Томат":"красный"}
for Fruit,color in MyFruitDict.items():
    if "к" in color :
      print(Fruit)
# Out:
# Дуриан
# Томат
